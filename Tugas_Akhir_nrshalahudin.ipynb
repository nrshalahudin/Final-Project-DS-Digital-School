# %% [markdown]
# Tugas ini berupa Tugas Akhir yang diselesaikan pada Akhir Pekan 8. Tugas disusun sesuai dengan materi yang diberikan tiap harinya dari pekan 1-8.

# %% [markdown]
# # Dataset
#
# silahkan unduh dataset berikut untuk mengerjakan Tugas Akhir:
#
# [pelanggan_supermarket.csv](https://drive.google.com/uc?export=download&id=1jaxCbZ4fcCneeVCEN-yuxWE0RyX25tbQ)

# %% [markdown]
# ---
#
#
#
# ---
#
#
#
# ---

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
import pandas as pd

df = pd.read_csv('/content/pelanggan_supermarket (1).csv')
df
# Out:
#      ID_pelanggan Jenis Kelamin   Umur  Pendapatan pertahun (juta)  \
# 0               1     Laki-laki   19.0                          15
# 1               2     Laki-laki   21.0                          15
# 2               3     Perempuan   20.0                          16
# 3               4     Perempuan   23.0                          16
# 4               5     Perempuan   31.0                          17
# ..            ...           ...    ...                         ...
# 245           246     Laki-laki   59.0                          93
# 246           247     Laki-laki   35.0                          93
# 247           248     Perempuan   37.0                          97
# 248           249     Perempuan   32.0                          97
# 249           250     Laki-laki  120.0                          98
#
#      Skor Belanja (1-100)
# 0                    39.0
# 1                    81.0
# 2                     6.0
# 3                    77.0
# ...

# %% [markdown]
# ---
#
#
#
# ---
#
#
#
# ---

# %% [markdown]
# # Soal 1. Statistika Deskriptif
#
# lakukan eksplorasi data dengan menggunakan statistika deskriptif. Gunakan pandas untuk mendapatkan summary statistics, dan analisa hasil yang ditampilkan.

# %%
#code here
print(df.describe)
# Out:
# <bound method NDFrame.describe of      ID_pelanggan Jenis Kelamin   Umur  Pendapatan pertahun (juta)  \
# 0               1     Laki-laki   19.0                          15
# 1               2     Laki-laki   21.0                          15
# 2               3     Perempuan   20.0                          16
# 3               4     Perempuan   23.0                          16
# 4               5     Perempuan   31.0                          17
# ..            ...           ...    ...                         ...
# 245           246     Laki-laki   59.0                          93
# 246           247     Laki-laki   35.0                          93
# 247           248     Perempuan   37.0                          97
# 248           249     Perempuan   32.0                          97
# 249           250     Laki-laki  120.0                          98
#
#      Skor Belanja (1-100)
# 0                    39.0
# 1                    81.0
# 2                     6.0
# ...

# %% [markdown]
# **Expected output**
#
# ![](https://drive.google.com/uc?id=1-5_d0Ey1lWMXj0d8ABimuPqqTz-h-8mx)

# %% [markdown]
# Give your analysis:

# %% [markdown]
# Jumlah Data: Jumlah total data pelanggan adalah 250.
#
# Umur Pelanggan: Rata-rata umur pelanggan adalah sekitar 38.73 tahun. Standar deviasi umur adalah sekitar 14.33 tahun. Umur minimum pelanggan adalah 18 tahun, sementara umur maksimum adalah 120 tahun. Terdapat 5 data yang tidak memiliki informasi mengenai umur (missing values), karena hanya terdapat 245 nilai pada kolom tersebut. Pendapatan Pertahun:
#
# Rata-rata pendapatan pertahun pelanggan adalah sekitar 64.74 juta. Standar deviasi pendapatan pertahun adalah sekitar 25.11 juta. Pendapatan pertahun minimum pelanggan adalah 15 juta, sedangkan pendapatan pertahun maksimum adalah 137 juta.
#
# Skor Belanja: Rata-rata skor belanja pelanggan adalah sekitar 50.33. Standar deviasi skor belanja adalah sekitar 28.67. Skor belanja minimum pelanggan adalah 3, sedangkan skor belanja maksimum adalah 150. Terdapat 4 data yang tidak memiliki informasi mengenai skor belanja (missing values), karena hanya terdapat 246 nilai pada kolom tersebut.

# %% [markdown]
# ---
#
#
#
# ---
#
#
#
# ---

# %% [markdown]
# # Soal 2. Handling missing value
#
# Jika dilihat dari summary statistik terlihat dataset memiliki nilai missing. Hitunglah jumlah missing value menggunakan methode .isnull().
#
# Isi nilai nan dengan nilai sebelumnya di row tersebut. gunakan method .fillna() dengan argument method bernilai 'ffill', baca dokumentasi https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.fillna.html

# %%
#code here
jumlah_missing = df.isnull().sum()
print(jumlah_missing)
df = df.fillna(method='ffill')
# Out:
# ID_pelanggan                  0
# Jenis Kelamin                 0
# Umur                          0
# Pendapatan pertahun (juta)    0
# Skor Belanja (1-100)          0
# dtype: int64

# %% [markdown]
# ---
#
#
#
# ---
#
#
#
# ---

# %% [markdown]
# # Soal 3. Handling outlier
#
# 1. Apakah data set memiliki nilai pencilan untuk setiap kolom? periksalah dengan melakukan visualisasi menggunakan boxplot.
# 2. Handling outlier tersebut dengan menggunakan teknik trimming / removing outliers (menggunakan teknik IQR)
# 3. simpan data hasil handling outlier ke dalam variabel df2
# 4. Teknik ini akan menghasilkan nilai missing pada nilai outlier yang telah dihapus, maka hapuslah data missing tersebut dengan menggunakan method .dropna()

# %%
#code here
plt.figure(figsize=(10, 6))
plt.subplot(2, 2, 1)
sns.boxplot(x=df['ID_pelanggan'])
plt.title('Boxplot ID_pelanggan')
plt.subplot(2, 2, 2)
sns.boxplot(x=df['Umur'])
plt.title('Boxplot Umur')
plt.subplot(2, 2, 3)
sns.boxplot(x=df['Pendapatan pertahun (juta)'])
plt.title('Boxplot Pendapatan pertahun')
plt.subplot(2, 2, 4)
sns.boxplot(x=df['Skor Belanja (1-100)'])
plt.title('Boxplot Skor Belanja')
plt.tight_layout()
plt.show()

Q1 = np.percentile(df['ID_pelanggan'], 25)
Q3 = np.percentile(df['ID_pelanggan'], 75)
IQR = Q3 - Q1
lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR
df = df[(df['ID_pelanggan'] >= lower_bound) & (df['ID_pelanggan'] <= upper_bound)]

Q1 = np.percentile(df['Umur'], 25)
Q3 = np.percentile(df['Umur'], 75)
IQR = Q3 - Q1
lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR
df = df[(df['Umur'] >= lower_bound) & (df['Umur'] <= upper_bound)]

Q1 = np.percentile(df['Pendapatan pertahun (juta)'], 25)
Q3 = np.percentile(df['Pendapatan pertahun (juta)'], 75)
IQR = Q3 - Q1
lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR
df = df[(df['Pendapatan pertahun (juta)'] >= lower_bound) & (df['Pendapatan pertahun (juta)'] <= upper_bound)]

Q1 = np.percentile(df['Skor Belanja (1-100)'], 25)
Q3 = np.percentile(df['Skor Belanja (1-100)'], 75)
IQR = Q3 - Q1
lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR
df = df[(df['Skor Belanja (1-100)'] >= lower_bound) & (df['Skor Belanja (1-100)'] <= upper_bound)]

df2 = df.copy()
df2 = df2.dropna()

# %% [markdown]
# **Expected output**
#
# Melihat adanya pencilan menggunakan Boxplot
#
# ![](https://drive.google.com/uc?id=1ettD4G8xBMCYcMUVt88kn5k_yCufgdyf)

# %% [markdown]
# ---
#
#
#
# ---
#
#
#
# ---

# %% [markdown]
# # Soal 4. statistika Inferential
#
#
#
# *   Kita akan melakukan hipotesis terhadap 100 sample pengunjung Supermarket. Hipotesis awal adalah rata2 usia pengunjung supermarket di atas 35 tahun. Ujilah hipotesis tersebut dengan menggunakan teknik klasik (z-testing) dan probabilitas p-value)!
# *   Gunakan variabel dataframe hasil handling missing value dan outlier di no soal sebelumnya
# *   Untuk mempermudah perhitungan, ubahlah tipe data kolom Umur menjadi int dengan menggunakan methode .astype() baca dokumentasi https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.astype.html

# %%
df_100 = df2.sample(100,  random_state=1)
df2['Umur'] = df2['Umur'].astype(int)

# %%
#code here for z-test
from scipy.stats import norm
mean_h0 = 35
alpha = 0.05
sample_mean = np.mean(df2)
sample_std = np.std(df2, ddof=1)
n = len(df2)
z_score = (sample_mean - mean_h0) / (sample_std / np.sqrt(n))
z_critical = norm.ppf(1 - alpha)
print('Nilai z-score:', z_score)
print('Nilai kritis z:', z_critical)
# Out:
# Nilai z-score: ID_pelanggan                  19.411407
# Umur                           3.921727
# Pendapatan pertahun (juta)    18.954643
# Skor Belanja (1-100)           8.424942
# dtype: float64
# Nilai kritis z: 1.6448536269514722

# %%
#code here for p-value
p_value = 1 - norm.cdf(z_score)
print('Nilai p-value:', p_value)
# Out:
# Nilai p-value: [0.00000000e+00 4.39583568e-05 0.00000000e+00 0.00000000e+00]

# %% [markdown]
# Give your analysis:

# %% [markdown]
# ID_pelanggan memiliki nilai z-score sebesar 19.411407, yang jauh lebih besar dari nilai kritis z sebesar 1.6448536269514722. Umur memiliki nilai z-score sebesar 3.921727, yang juga jauh lebih besar dari nilai kritis z. Pendapatan pertahun (juta) memiliki nilai z-score sebesar 18.954643, yang juga jauh lebih besar dari nilai kritis z. Skor Belanja (1-100) memiliki nilai z-score sebesar 8.424942, yang juga jauh lebih besar dari nilai kritis z. Berdasarkan nilai p-value yang telah dihitung, kita dapat membuat kesimpulan sebagai berikut:
#
# Semua nilai p-value yang dihasilkan adalah sangat kecil (p-value < 0.0001), yang menunjukkan bahwa terdapat cukup bukti untuk menolak hipotesis nol. Oleh karena itu, kita dapat menyimpulkan bahwa rata-rata usia pengunjung supermarket, ID pelanggan, pendapatan pertahun, dan skor belanja semuanya lebih dari nilai 35 tahun (berdasarkan hipotesis alternatif). Dalam konteks ini, hasil uji hipotesis menunjukkan bahwa rata-rata usia pengunjung supermarket dan variabel lainnya secara signifikan lebih dari 35 tahun.

# %% [markdown]
# ---
#
#
#
# ---
#
#
#
# ---

# %% [markdown]
# ## Soal 5. EDA

# %% [markdown]
# Lakukan eksplorasi data analisis. Gunakan visualisasi distplot untuk melihat sebaran data dan histogram pada setiap kolom dataset awal sebelum dilakukan handling missing value maupun outlier

# %%
#code here for univariate
fig, axs = plt.subplots(3, 2, figsize=(8, 8))
sns.distplot(df['ID_pelanggan'], ax=axs[0, 0])
axs[0, 0].set_title('ID_pelanggan')
sns.distplot(df['Umur'], ax=axs[0, 1])
axs[0, 1].set_title('Umur')
sns.distplot(df['Pendapatan pertahun (juta)'], ax=axs[1, 0])
axs[1, 0].set_title('Pendapatan pertahun (juta)')
sns.distplot(df['Skor Belanja (1-100)'], ax=axs[1, 1])
axs[1, 1].set_title('Skor Belanja (1-100)')
axs[2, 0].axis('off')
axs[2, 1].axis('off')
plt.tight_layout()
plt.show()

# %% [markdown]
# Give your analysis:

# %% [markdown]
# ID_pelanggan: Distribusi data pada kolom ID_pelanggan terlihat merata dengan sedikit variasi. Histogram menunjukkan bahwa setiap ID_pelanggan memiliki frekuensi yang hampir sama.
#
# Umur: Distribusi data pada kolom Umur terlihat cenderung simetris dengan puncak di sekitar 30-40 tahun. Histogram menunjukkan bahwa jumlah pengunjung supermarket cenderung tinggi pada kelompok usia tersebut.
#
# Pendapatan pertahun (juta): Distribusi data pada kolom Pendapatan pertahun terlihat cenderung miring ke kanan. Hal ini menunjukkan bahwa sebagian besar pengunjung supermarket memiliki pendapatan yang relatif rendah. Histogram menunjukkan bahwa frekuensi pengunjung cenderung tinggi pada pendapatan di rentang yang lebih rendah.
#
# Skor Belanja (1-100): Distribusi data pada kolom Skor Belanja terlihat cukup simetris dengan puncak di sekitar nilai 40-60. Hal ini menunjukkan bahwa sebagian besar pengunjung memiliki skor belanja yang relatif sedang. Histogram menunjukkan bahwa frekuensi pengunjung cenderung tinggi pada rentang skor belanja tersebut.

# %%
#code here for bivariate
fig, axs = plt.subplots(2, 2, figsize=(8, 6))
sns.scatterplot(x='Umur', y='Pendapatan pertahun (juta)', data=df, ax=axs[0, 0])
axs[0, 0].set_title('Umur vs. Pendapatan pertahun')
sns.scatterplot(x='Umur', y='Skor Belanja (1-100)', data=df, ax=axs[0, 1])
axs[0, 1].set_title('Umur vs. Skor Belanja')
sns.scatterplot(x='Pendapatan pertahun (juta)', y='Skor Belanja (1-100)', data=df, ax=axs[1, 0])
axs[1, 0].set_title('Pendapatan pertahun vs. Skor Belanja')
axs[1, 1].axis('off')
plt.tight_layout()
plt.show()

# %% [markdown]
# Give your analysis:

# %% [markdown]
# Umur vs. Pendapatan pertahun: visualisasi ini memperlihatkan hubungan antara umur pengunjung dengan pendapatan pertahun. Terlihat bahwa tidak ada pola yang jelas antara kedua variabel ini. Titik-titik data tersebar di berbagai rentang umur dan pendapatan, tanpa adanya hubungan yang konsisten.
#
# Umur vs. Skor Belanja: Visualisasi ini memperlihatkan hubungan antara umur pengunjung dengan skor belanja. Terlihat bahwa tidak ada hubungan yang kuat antara umur dan skor belanja. Titik-titik data tersebar secara acak dan tidak membentuk pola yang terlihat jelas.
#
# Pendapatan pertahun vs. Skor Belanja: Visualisasi ini memperlihatkan hubungan antara pendapatan pertahun dengan skor belanja. Terlihat adanya tren yang menunjukkan bahwa semakin tinggi pendapatan pertahun, skor belanja cenderung meningkat. Namun, masih ada variasi yang signifikan di setiap rentang pendapatan, sehingga tidak bisa ditarik kesimpulan yang kuat.

# %%
#code here for multivariate
corr_matrix = df.corr()
custom_palette = ["#8B5C94", "black", "#FFB6C1", "#FFDAB9"]
plt.figure(figsize=(6, 4))
sns.heatmap(corr_matrix, annot=True, cmap=custom_palette)
plt.title('Multivariate')
plt.show()

# %% [markdown]
# Give your analysis:

# %% [markdown]
# perbandingan antara umur dengan skor belanja relatif cukup rendah dilihat dari kolom warna yang lebih gelap pada grafik,
# korelasi pendapatan per tahun dengan skor belanja relatif lebih baik jika dibandingkan dengan korelasi sebelumnya (umur dengan skor belanja),
# tren lebih positif terlihat antara skor belanja dengan ID_pelanggan yang menandakan bahwa pelanggan pada restoran tersebut relatif stabil.

# %% [markdown]
# **Expected output**
#
# Univariate plot
#
# ![](https://drive.google.com/uc?id=12BSOah7WFzuOEJsKfsaNDw799zzqbDIs)
#
# Bivariate plot
#
# ![](https://drive.google.com/file/d/1aNLD2M9a-d63sVkCqN7n475LQ8NqSsi1/)
#
# Multivariate plot
#
# ![](https://drive.google.com/uc?id=1TTXm3BjoqqwSGMGE1en9ZIJT53Wm5SFf)

# %% [markdown]
# ---
#
# ---
#
#
#
# ---

# %% [markdown]
# # Soal 6. Data scaling
# lakukan scaling data dengan menggunakan standarisasi untuk kolom Umur dan skor belanja saja tetapi menggunakan variabel dataframe setelah handling missing value dan outlier

# %%
#code here
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
data_to_scale = df2[['Umur', 'Skor Belanja (1-100)']]
scaled_data = scaler.fit_transform(data_to_scale)
df2_scaled = pd.DataFrame(scaled_data, columns=['Umur', 'Skor Belanja  (1-100)'])
print(df2_scaled.head())
# Out:
#        Umur  Skor Belanja  (1-100)
# 0 -1.450802              -0.396061
# 1 -1.300899               1.120127
# 2 -1.375851              -1.587352
# 3 -1.150996               0.975728
# 4 -0.551385              -0.359962

# %% [markdown]
# ---
#
#
#
# ---
#
#
#
# ---

# %% [markdown]
# # Soal 7. Clustering menggunakan k-menas
#
# *   Lakukan clustering menggunakan kmeans clustering dengan k =2, dan visualisasikan
# *   Gunakan Elbow method untuk menemukan jumlah k kluster yang tepat
# *   Gunakan k=3 (rekomendasi methode Elbow) lalu visualisasikan
# *   Hitung silhoutte Coefficient dari ke dua hasil prediksi klustering tersebut

# %%
#code here
from sklearn.cluster import KMeans
data_for_clustering = df2[['Umur', 'Skor Belanja (1-100)']]
plt.figure(figsize=(8, 6))
kmeans = KMeans(n_clusters=2)
kmeans.fit(data_for_clustering)
labels = kmeans.labels_
df2['Cluster'] = labels
plt.scatter(df2['Umur'], df2['Skor Belanja (1-100)'], c=df2['Cluster'], cmap='coolwarm')
plt.scatter(centers[:, 0], centers[:, 1], c='black', marker='o', s=200, edgecolor='black', linewidth=2)
plt.xlabel('Umur')
plt.ylabel('Skor Belanja (1-100)')
plt.show()

# %%
#code here
inertias = []
for k in range(1, 11):
    kmeans = KMeans(n_clusters=k, random_state=42)
    kmeans.fit(df2[['Umur', 'Skor Belanja (1-100)']])
    inertias.append(kmeans.inertia_)
plt.plot(range(1, 11), inertias)
plt.xlabel('Jumlah Kluster (k)')
plt.ylabel('wcss')
plt.title('Elbow Method')
plt.show()

# %%
#code here
kmeans = KMeans(n_clusters=3, random_state=42)
kmeans.fit(df2[['Umur', 'Skor Belanja (1-100)']])
labels = kmeans.labels_
centers = kmeans.cluster_centers_
plt.scatter(df2['Umur'], df['Skor Belanja (1-100)'], c=labels, cmap='viridis')
plt.scatter(centers[:, 0], centers[:, 1], c='black', marker='o', s=200)
plt.xlabel('Umur')
plt.ylabel('Skor Belanja (1-100)')
plt.show()

# %% [markdown]
# **Expected output**
#
# cluster 2
#
# ![](https://drive.google.com/uc?id=1L7nIskGXbeXGhKOzhMWCykJ4jY5538mn)
#
# elbow method
#
# ![](https://drive.google.com/uc?id=1a3OL9FhiQ2-DyJQ8sg8PNzfS9QsszyvU)
#
# cluster 3
#
# ![](https://drive.google.com/uc?id=1UR6vK36oLJinLPtechjJJBtxifmdFOSn)

# %%
#silhoutte score
from sklearn.metrics import silhouette_score
kmeans2 = KMeans(n_clusters=2, random_state=42)
kmeans2.fit(df[['Umur', 'Skor Belanja (1-100)']])
labels2 = kmeans2.labels_
silhouette_score_2 = silhouette_score(df[['Umur', 'Skor Belanja (1-100)']], labels2)
kmeans3 = KMeans(n_clusters=3, random_state=42)
kmeans3.fit(df[['Umur', 'Skor Belanja (1-100)']])
labels3 = kmeans3.labels_
silhouette_score_3 = silhouette_score(df[['Umur', 'Skor Belanja (1-100)']], labels3)
print("Silhouette Coefficient (k=2):", silhouette_score_2)
print("Silhouette Coefficient (k=3):", silhouette_score_3)
# Out:
# Silhouette Coefficient (k=2): 0.5028194097989681
# Silhouette Coefficient (k=3): 0.4825282709883241

# %% [markdown]
# ---
#
#
#
# ---
#
#
#
# ---

# %% [markdown]
# # Soal 8. Analyze clustering result

# %% [markdown]
# Dari hasil klustering diatas, buatlah sebuah analisa segmentasi pelanggan untuk targetted market supermarket

# %% [markdown]
# Berdasarkan hasil klustering yang telah dilakukan, kita dapat melakukan analisis segmentasi pelanggan untuk target market supermarket. Dalam visualisasi jaki ini menggunakan variabel Umur dan Skor Belanja (1-100) untuk melakukan klustering.
#
# Klustering dengan k=2:
# Terdapat dua segmen pelanggan yang teridentifikasi: Segmen A dan Segmen B.
# Segmen A ditandai dengan umur yang lebih muda dan skor belanja yang rendah, sedangkan Segmen B ditandai dengan umur yang lebih tua dan skor belanja yang lebih tinggi.
# Segmen A dapat dianggap sebagai pelanggan yang memiliki potensi pertumbuhan dalam hal peningkatan skor belanja mereka.
# Segmen B dapat dianggap sebagai pelanggan yang lebih mapan dan memiliki kecenderungan untuk melakukan pembelian yang lebih besar.
#
# Klustering dengan k=3:
# Terdapat tiga segmen pelanggan yang teridentifikasi: Segmen A, Segmen B, dan Segmen C.
# Segmen A ditandai dengan umur yang lebih muda dan skor belanja yang rendah.
# Segmen B ditandai dengan umur yang sedang dan skor belanja yang sedang.
# Segmen C ditandai dengan umur yang lebih tua dan skor belanja yang lebih tinggi.
# Segmen A dapat dianggap sebagai pelanggan yang perlu lebih banyak upaya pemasaran untuk meningkatkan skor belanja mereka.
# Segmen B dapat dianggap sebagai pelanggan yang stabil dengan tingkat belanja yang sedang.
# Segmen C dapat dianggap sebagai pelanggan yang merupakan target pasar potensial dengan potensi pembelian yang lebih besar.
# Analisis segmentasi pelanggan ini bisa digunakan untuk merancang strategi pemasaran yang lebih efektif. Misalnya, untuk Segmen A, supermarket dapat fokus pada upaya untuk menarik pelanggan yang lebih muda dan mendorong mereka untuk meningkatkan aktivitas belanja mereka. Sedangkan untuk Segmen C, supermarket dapat menyediakan layanan yang lebih eksklusif dan menargetkan promosi untuk meningkatkan loyalitas pelanggan yang sudah mapan.
